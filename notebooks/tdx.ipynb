# %%
# set current working directory
import os
if os.name == 'posix':
    # %cd ~/workspace/python/CNStocks
else:
    # %cd D:\workspace\python\CNStocks
        
from libs.utils import Utils
from libs.utils import ThreadedAsyncio

from random import randrange
from pytdx.hq import TdxHq_API
from pytdx.params import TDXParams
from pytdx.config.hosts import hq_hosts as tdx_hq_hosts
from pytdx.reader import TdxDailyBarReader, TdxFileNotFoundException

import json
import time
import math
import platform
import subprocess
import asyncio
import aioping
# Out:
# D:\workspace\python\CNStocks

# %%
class TDX:
    
    HQ_HOSTS_FILE = os.path.join(os.getcwd(), "tdx_hq_hosts.json")
    
    def __init__(self, root):
        
        self.root = root
        self.tdx = TdxHq_API(heartbeat=True, auto_retry=True)
        self.tdx_connect_to_server()
    
    @staticmethod
    async def ping(host):
        timeout = 999999
        try:
            delay = await aioping.ping(host[1]) * 1000
            print('ping host['+host[0]+', '+str(host[1])+':'+str(host[2])+'] ... ... ', round(delay,2), 'ms')
        except TimeoutError:
            delay = timeout
            print('ping host['+host[0]+', '+str(host[1])+':'+str(host[2])+'] ... ... timeout')
        return delay
    
    @staticmethod
    async def test_hosts(hosts):
        return await asyncio.gather(*[TDX.ping(host) for host in hosts])
    
    @staticmethod
    def find_available_hosts(hq_hosts=tdx_hq_hosts):
        thread = ThreadedAsyncio(target=TDX.test_hosts, args=(hq_hosts,))
        thread.start()
        results = thread.join()
        
        hosts = []
        for idx, host in enumerate(hq_hosts):
            if results[idx] > 500:
                continue
            host = [*host]
            if len(host) == 3:
                host.append(results[idx])
            else:
                host[-1] = results[idx]
            hosts.append(host)
            
        hosts.sort(key=lambda x : x[3])
        with open(TDX.HQ_HOSTS_FILE, "w") as f:
            f.write(json.dumps(hosts))
            
        return hosts
    
    def tdx_connect_to_server(self):
        
        if not os.path.exists(TDX.HQ_HOSTS_FILE):
            print('use default server: ', '202.108.253.130:7709')
            print('please run TDX.find_available_hosts to test out the fastest servers')
            self.tdx.connect('202.108.253.130', 7709)
            
        else:
            with open(TDX.HQ_HOSTS_FILE) as f:
                hosts = json.load(f)
                
            hosts = TDX.find_available_hosts(hq_hosts=hosts)
            for host in hosts:
                try:
                    print('try to connect the fastest host:', host)
                    self.tdx.connect(host[1], host[2])
                    break
                except Exception as e:
                    print(str(e))
                    print('retry with next host')
            
    def get_tdx_gainian(self):

        fname = os.path.join(self.root,'T0002', 'hq_cache', 'block_gn.dat')
        result = {}
        if type(fname) is not bytearray:
            with open(fname, "rb") as f:
                data = f.read()
        else:
            data = fname

        pos = 384
        (num, ) = struct.unpack("<H", data[pos: pos + 2])
        pos += 2
        for i in range(num):
            blockname_raw = data[pos: pos + 9]
            pos += 9
            name = blockname_raw.decode("gbk", 'ignore').rstrip("\x00")
            stock_count, block_type = struct.unpack("<HH", data[pos: pos + 4])
            pos += 4
            block_stock_begin = pos
            codes = []
            for code_index in range(stock_count):
                one_code = data[pos: pos + 7].decode("utf-8", 'ignore').rstrip("\x00")
                codes.append(one_code)
                pos += 7

            gn = {}
            gn["name"] = name
            gn["block_type"] = block_type
            gn["stock_count"] = stock_count
            gn["codes"] = codes
            result[name] = gn

            pos = block_stock_begin + 2800

        return result
    
    def get_tdx_hangye(self):

        file_hangye = os.path.join(self.root, 'incon.dat')
        assert os.path.exists(file_hangye)
        file_stock_hangye = os.path.join(self.tdx_dir, 'T0002', 'hq_cache',' tdxhy.cfg')
        assert os.path.exists(file_stock_hangye)

        result = {}
        with open(file_hangye, "rt", encoding='gb2312') as f:
            isTDXHY = False
            for line in f:
                line = line.rstrip()
                if not isTDXHY and line != '#TDXNHY':
                    continue
                elif not isTDXHY and line == '#TDXNHY':
                    isTDXHY = True
                    continue
                elif isTDXHY and line == '######':
                    isTDXHY = False
                    break
                code, name = line.split('|')
                result[code] = {}
                result[code]['code'] = code
                result[code]['name'] = name
                result[code]['codes'] = []

        with open(file_stock_hangye, "rt", encoding='gb2312') as f:
            for line in f:
                line = line.rstrip()
                market_code, stock_code, tdxhy_code, swhy_code, unknown_code = line.split("|")
                stock_code = stock_code.strip()

                if tdxhy_code != 'T00':
                    result[tdxhy_code]['codes'].append(stock_code)
        return result
    
    def get_tdx_zhishu(self):

        tdxzs_cfg = os.path.join(self.root, 'T0002', 'hq_cache', 'tdxzs.cfg')
        gainian = self.get_tdx_gainian()
        hangye = self.get_tdx_hangye()

        result = {}
        with open(tdxzs_cfg, "rt", encoding='gb2312') as f:
            for line in f:
                line = line.rstrip()
                zs_name, zs_code, zs_type, num_1, num_2, key = line.split('|')

                if key in gainian:
                    if zs_code in result:
                        print('------------------------------------------------------')
                        print('in result key: ', key, zs_name, zs_code)
                        print('gainian: ', key, gainian[key])
                        continue
                    else:
                        if len(gainian[key]['codes']) == 0:
                            continue
                        zs = {}
                        zs['code'] = zs_code
                        zs['name'] = gainian[key]['name']
                        zs['codes'] = gainian[key]['codes']
                        result[zs_code] = zs

                if key in hangye:
                    if zs_code in result:
                        print('------------------------------------------------------')
                        print('in result key: ', key, zs_name, zs_code)
                        print('hangye: ', key, hangye[key])
                        continue
                    else:
                        if len(hangye[key]['codes']) == 0:
                            continue
                        zs = {}
                        zs['code'] = zs_code
                        zs['name'] = hangye[key]['name']
                        zs['codes'] = hangye[key]['codes']
                        result[zs_code] = zs

        return result

    def is_tdx_local_data_ready_for(self, dt):
        file = os.path.join(self.root, 'vipdoc', 'sz', 'lday', 'sz399001.day')
        reader = TdxDailyBarReader()
        df = reader.get_df(file)

        return dt.strftime('%Y-%m-%d') in df.index
    
    def get_lastest_stock_codes(self):
        old_codes = Utils.get_stock_codes()
        code_filter = Utils.code_filter

        step_size = 1000
        codes = []
        for market in Utils.markets:

            count = self.tdx.get_security_count(market)
            print(market, count, end=' : ')

            steps = math.ceil(count/step_size)

            total = 0
            for step in range(steps):
                result = self.tdx.get_security_list(market, step_size*step)
                print(str(step)+'/'+str(steps), end=", ")
                for item in result:
                    code = item['code'].strip()
                    if code[:3] in code_filter[market]:
                        codes.append(code)
                        total += 1
            
            market_name = '深市' if market == 0 else '沪市'
            print(market_name + ' A股 总数: '+str(total))
        print('沪深 A股 总数:'+str(len(codes)))
        return codes

# %%
root = 'C:\\tdx\\tdx_7.46'
tdx = TDX(root)
# Out:
# ping host[华林, 120.55.172.97:7709] ... ...  420.76 ms
# ping host[北京联通主站Z1, 202.108.253.130:7709] ... ...  429.77 ms
# ping host[杭州联通主站J2, 60.12.136.250:7709] ... ...  429.83 ms
# ping host[北京联通主站Z2, 202.108.253.131:7709] ... ...  432.52 ms
# ping host[北京联通主站Z80, 202.108.253.139:80] ... ...  432.82 ms
# ping host[广发, 123.138.29.107:7709] ... ...  431.99 ms
# ping host[华泰证券(上海电信), 101.227.73.20:7709] ... ...  436.34 ms
# ping host[国泰君安, 117.34.114.20:7709] ... ...  434.53 ms
# ping host[国泰君安, 117.34.114.16:7709] ... ...  435.57 ms
# ping host[华泰证券(武汉电信), 59.173.18.140:7709] ... ...  438.86 ms
# ping host[华林, 220.178.55.71:7709] ... ...  438.4 ms
# ping host[国泰君安, 117.34.114.31:7709] ... ...  439.83 ms
# ping host[国泰君安, 117.34.114.27:7709] ... ...  442.07 ms
# ping host[国泰君安, 117.34.114.17:7709] ... ...  443.6 ms
# ping host[国泰君安, 117.34.114.15:7709] ... ...  444.4 ms
# ping host[安信, 59.36.5.11:7709] ... ...  444.7 ms
# ping host[国泰君安, 117.34.114.14:7709] ... ...  447.36 ms
# ping host[国泰君安, 117.34.114.18:7709] ... ...  447.21 ms
# ping host[国泰君安, 117.34.114.13:7709] ... ...  449.37 ms
# ping host[国泰君安, 117.34.114.30:7709] ... ...  449.28 ms
# ping host[长城国瑞网通, 58.23.131.163:7709] ... ...  451.66 ms
# ping host[国泰君安, 113.105.92.103:7709] ... ...  449.88 ms
# ping host[华泰证券(深圳电信), 14.215.128.18:7709] ... ...  452.96 ms
# ping host[招商证券深圳行情, 119.147.212.81:7709] ... ...  453.33 ms
# ping host[国泰君安, 113.105.92.100:7709] ... ...  450.22 ms
# ping host[国泰君安, 113.105.92.104:7709] ... ...  453.04 ms
# ping host[国泰君安, 113.105.92.101:7709] ... ...  453.62 ms
# ping host[国泰君安, 113.105.92.102:7709] ... ...  540.35 ms
# ping host[国泰君安, 113.105.92.99:7709] ... ...  540.8 ms
# ping host[华林, 202.96.138.90:7709] ... ...  544.45 ms
# try to connect the fastest host: ['华林', '120.55.172.97', 7709, 420.76059999999416]
# head_buf is not 0x10 : b''
# retry with next host
# try to connect the fastest host: ['北京联通主站Z1', '202.108.253.130', 7709, 429.7652999999855]

# %%
now = datetime.now()
dt = now-timedelta(days=6)
tdx.is_tdx_local_data_ready_for(dt)

# %%
tdx.get_lastest_stock_codes()

# %%
TDX.find_available_hosts()
# Out:
# ping host[北京联通主站Z1, 202.108.253.130:7709] ... ...  199.48 ms
# ping host[杭州联通主站J2, 60.12.136.250:7709] ... ...  201.43 ms
# ping host[北京联通主站Z2, 202.108.253.131:7709] ... ...  204.5 ms
# ping host[华泰证券(上海电信), 101.227.73.20:7709] ... ...  199.9 ms
# ping host[北京联通主站Z80, 202.108.253.139:80] ... ...  207.86 ms
# ping host[华泰证券(武汉电信), 59.173.18.140:7709] ... ...  202.52 ms
# ping host[长城国瑞网通, 58.23.131.163:7709] ... ...  226.29 ms
# ping host[招商证券深圳行情, 119.147.212.81:7709] ... ...  221.68 ms
# ping host[华泰证券(深圳电信), 14.215.128.18:7709] ... ...  222.67 ms
# ping host[国泰君安, 113.105.92.104:7709] ... ...  249.24 ms
# ping host[国泰君安, 117.34.114.13:7709] ... ...  251.93 ms
# ping host[华林, 220.178.55.71:7709] ... ...  247.75 ms
# ping host[国泰君安, 117.34.114.14:7709] ... ...  253.64 ms
# ping host[国泰君安, 117.34.114.15:7709] ... ...  255.07 ms
# ping host[国泰君安, 117.34.114.16:7709] ... ...  256.26 ms
# ping host[国泰君安, 117.34.114.17:7709] ... ...  257.47 ms
# ping host[国泰君安, 117.34.114.18:7709] ... ...  258.54 ms
# ping host[国泰君安, 117.34.114.20:7709] ... ...  259.51 ms
# ping host[国泰君安, 117.34.114.27:7709] ... ...  260.42 ms
# ping host[国泰君安, 117.34.114.30:7709] ... ...  261.38 ms
# ping host[国泰君安, 117.34.114.31:7709] ... ...  262.23 ms
# ping host[广发, 123.138.29.107:7709] ... ...  271.68 ms
# ping host[华林, 120.55.172.97:7709] ... ...  286.04 ms
# ping host[国泰君安, 113.105.92.101:7709] ... ...  300.01 ms
# ping host[国泰君安, 113.105.92.103:7709] ... ...  300.89 ms
# ping host[安信, 59.36.5.11:7709] ... ...  306.55 ms
# ping host[国泰君安, 113.105.92.100:7709] ... ...  307.88 ms
# ping host[国泰君安, 113.105.92.102:7709] ... ...  326.71 ms
# ping host[国泰君安, 113.105.92.99:7709] ... ...  330.16 ms
# ping host[华林, 202.96.138.90:7709] ... ...  326.5 ms
# ping host[上证云北京联通一, 123.125.108.14:7709] ... ... timeout
# ping host[义乌移动主站J1, 223.94.89.115:7709] ... ... timeout
# ping host[上证云成都电信一, 218.6.170.47:7709] ... ... timeout
# ping host[杭州电信主站J2, 115.238.56.198:7709] ... ... timeout
# ping host[华泰证券(南京电信), 221.231.141.60:7709] ... ... timeout
# ping host[上海电信主站Z2, 180.153.18.171:7709] ... ... timeout
# ping host[上海电信主站Z80, 180.153.18.172:80] ... ... timeout
# ping host[华泰证券(天津联通), 60.28.23.80:7709] ... ... timeout
# ping host[青岛联通主站W1, 218.57.11.101:7709] ... ... timeout
# ping host[深圳电信主站Z1, 14.17.75.71:7709] ... ... timeout
# ping host[青岛电信主站W1, 58.58.33.123:7709] ... ... timeout
# ping host[杭州华数主站J1, 218.108.98.244:7709] ... ... timeout
# ping host[杭州联通主站J1, 124.160.88.183:7709] ... ... timeout
# ping host[华泰证券(沈阳联通), 218.60.29.136:7709] ... ... timeout
# ping host[安信, 112.95.140.74:7709] ... ... timeout
# ping host[安信, 114.80.149.19:7709] ... ... timeout
# ping host[上海电信主站Z3, 180.153.39.51:7709] ... ... timeout
# ping host[云行情上海电信Z1, 114.80.63.12:7709] ... ... timeout
# ping host[长城国瑞电信1, 218.85.139.19:7709] ... ... timeout
# ping host[上海电信主站Z1, 180.153.18.170:7709] ... ... timeout
# ping host[云行情上海电信Z2, 114.80.63.35:7709] ... ... timeout
# ping host[长城国瑞电信2, 218.85.139.20:7709] ... ... timeout
# ping host[杭州华数主站J2, 218.108.47.69:7709] ... ... timeout
# ping host[华泰证券(南京联通), 122.192.35.44:7709] ... ... timeout
# ping host[杭州电信主站J3, 218.75.126.9:7709] ... ... timeout
# ping host[安信, 112.95.140.93:7709] ... ... timeout
# ping host[华泰证券(南京联通), 122.192.35.44:7709] ... ... timeout
# ping host[安信, 112.95.140.92:7709] ... ... timeout
# ping host[杭州电信主站J1, 60.191.117.167:7709] ... ... timeout
# ping host[杭州电信主站J4, 115.238.90.165:7709] ... ... timeout
# ping host[华泰证券(上海电信二), 101.227.77.254:7709] ... ... timeout
# ping host[华林, 139.217.20.27:7709] ... ... timeout
# ping host[海通, 58.63.254.217:7709] ... ... timeout
# ping host[广发, 183.57.72.24:7709] ... ... timeout
# ping host[安信, 121.14.104.60:7709] ... ... timeout
# ping host[国信, 58.210.106.91:7709] ... ... timeout
# ping host[安信, 123.126.133.21:7709] ... ... timeout
# ping host[海通, 58.63.254.191:7709] ... ... timeout
# ping host[广发, 183.60.224.177:7709] ... ... timeout
# ping host[海通, 202.100.166.27:7709] ... ... timeout
# ping host[安信, 123.126.133.13:7709] ... ... timeout
# ping host[广发, 183.57.72.23:7709] ... ... timeout
# ping host[广发, 183.57.72.22:7709] ... ... timeout
# ping host[安信, 211.139.150.61:7709] ... ... timeout
# ping host[海通, 182.131.3.245:7709] ... ... timeout
# ping host[广发, 183.57.72.12:7709] ... ... timeout
# ping host[海通, 175.6.5.153:7709] ... ... timeout
# ping host[海通, 123.125.108.90:7709] ... ... timeout
# ping host[广发, 183.57.72.11:7709] ... ... timeout
# ping host[广发, 124.232.142.29:7709] ... ... timeout
# ping host[广发, 183.57.72.13:7709] ... ... timeout
# ping host[国信, 183.60.224.11:7709] ... ... timeout
# ping host[国信, 58.63.254.216:7709] ... ... timeout
# ping host[安信, 123.126.133.14:7709] ... ... timeout
# ping host[安信, 121.14.104.66:7709] ... ... timeout
# ping host[安信, 114.80.149.91:7709] ... ... timeout
# ping host[华林, 218.106.92.182:7709] ... ... timeout
# ping host[海通, 222.161.249.156:7709] ... ... timeout
# ping host[华林, 218.106.92.183:7709] ... ... timeout
# ping host[华林, 202.100.166.21:7709] ... ... timeout
# ping host[海通, 182.118.47.151:7709] ... ... timeout
# ping host[安信, 114.80.149.21:7709] ... ... timeout
# ping host[国信, 58.63.254.219:7709] ... ... timeout
# ping host[安信, 114.80.149.92:7709] ... ... timeout
# ping host[广发, 123.138.29.108:7709] ... ... timeout
# ping host[国信, 182.131.3.252:7709] ... ... timeout
# ping host[海通, 42.123.69.62:7709] ... ... timeout
# ping host[广发, 183.57.72.15:7709] ... ... timeout
# ping host[国信, 58.63.254.247:7709] ... ... timeout
# ping host[安信, 114.80.149.22:7709] ... ... timeout
# ping host[广发, 119.29.19.242:7709] ... ... timeout
# ping host[广发, 183.57.72.21:7709] ... ... timeout
# ping host[华林, 220.178.55.86:7709] ... ... timeout
# ping host[广发, 183.60.224.178:7709] ... ... timeout
# [['北京联通主站Z1', '202.108.253.130', 7709, 199.4811999999797],
#  ['华泰证券(上海电信)', '101.227.73.20', 7709, 199.8954000000026],
#  ['杭州联通主站J2', '60.12.136.250', 7709, 201.4308999999912],
#  ['华泰证券(武汉电信)', '59.173.18.140', 7709, 202.52319999997326],
#  ['北京联通主站Z2', '202.108.253.131', 7709, 204.50479999999516],
#  ['北京联通主站Z80', '202.108.253.139', 80, 207.85570000003872],
#  ['招商证券深圳行情', '119.147.212.81', 7709, 221.68449999998074],
#  ['华泰证券(深圳电信)', '14.215.128.18', 7709, 222.67479999999296],
#  ['长城国瑞网通', '58.23.131.163', 7709, 226.2890000000084],
#  ['华林', '220.178.55.71', 7709, 247.74890000003325],
#  ['国泰君安', '113.105.92.104', 7709, 249.24029999999675],
#  ['国泰君安', '117.34.114.13', 7709, 251.93000000001575],
#  ['国泰君安', '117.34.114.14', 7709, 253.63759999999047],
#  ['国泰君安', '117.34.114.15', 7709, 255.07060000001047],
#  ['国泰君安', '117.34.114.16', 7709, 256.26469999997425],
#  ['国泰君安', '117.34.114.17', 7709, 257.4728000000164],
#  ['国泰君安', '117.34.114.18', 7709, 258.5378999999648],
#  ['国泰君安', '117.34.114.20', 7709, 259.5052000000351],
#  ['国泰君安', '117.34.114.27', 7709, 260.4198000000224],
#  ['国泰君安', '117.34.114.30', 7709, 261.3754000000199],
#  ['国泰君安', '117.34.114.31', 7709, 262.22740000002887],
#  ['广发', '123.138.29.107', 7709, 271.68130000001156],
#  ['华林', '120.55.172.97', 7709, 286.0425999999734],
#  ['国泰君安', '113.105.92.101', 7709, 300.01240000001417],
#  ['国泰君安', '113.105.92.103', 7709, 300.89029999999184],
#  ['安信', '59.36.5.11', 7709, 306.5478999999982],
#  ['国泰君安', '113.105.92.100', 7709, 307.8840000000014],
#  ['华林', '202.96.138.90', 7709, 326.50019999999813],
#  ['国泰君安', '113.105.92.102', 7709, 326.7098999999689],
#  ['国泰君安', '113.105.92.99', 7709, 330.1622999999836]]

# %%
async def test_hosts(hosts):
    return await asyncio.gather(*[ping(host) for host in hosts])

# %%
results = await test_hosts(tdx_hq_hosts)

# %%
results

# %%
thread = ThreadedAsyncio(target=test_hosts, args=(tdx_hq_hosts,))
thread.start()
results = thread.join()

# %%
hosts = tdx_hq_hosts[:]
